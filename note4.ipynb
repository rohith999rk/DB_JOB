# %%
data = {
    "name" : "Rohith",
    "city": "Kurnool"
}
print(data)

# %%
a = 23
b = 63
if a<b:
    print("a is less than b")
else:
    print("a is greater than b")

# %%
marks = 75
if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 45:
    print("Grade D")
elif marks >= 35:
    print("Grade E")
else:
    print("Fail")

# %%
# %sql
select avg(salary) as avarage, sum(salary) as total_salary_sum from workspace.default.employees
