# %%
# %python
print("hello world")

# %%
# %python
def function1():
  print("hello world")
       
function1()

# %%
def function2():
    list = [1,2,3]
    return list
function2()

# %%
def function3():
    set = {'a','b','c'}
    return set
function3()
