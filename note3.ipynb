-- %%
%sql
select sum(Salary) as Total_sum
from workspace.default.employees

-- %%
select count(`User Id`) as Users
from workspace.default.people_100

-- %%
select p.`User Id`, p.`First Name`, c.`First Name`
from workspace.default.people_100 p
left join workspace.default.Customers_100 c
  on p.`User Id` = c.`User Id`

-- %%
select c.`User Id`, c.`First Name`, p.`First Name`
from workspace.default.customers_100 c
right join workspace.default.people_100 p
on c.`User Id` = p.`User Id`
